# %%
#importing libraries required
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#data loading
df=pd.read_csv("/content/drive/MyDrive/Dataset_ML/owid-covid-data (1) (1).csv")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 258742      ZWE    Africa     Zimbabwe  2023-02-15     263642.0      559.0
# 258743      ZWE    Africa     Zimbabwe  2023-02-16     263642.0        NaN
# 258744      ZWE    Africa     Zimbabwe  2023-02-17     263642.0        NaN
# 258745      ZWE    Africa     Zimbabwe  2023-02-18     263642.0        NaN
# 258746      ZWE    Africa     Zimbabwe  2023-02-19     263642.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 258742              79.857        5662.0         3.0                0.429
# 258743                 NaN        5662.0         0.0                0.429
# 258744                 NaN        5662.0         0.0                0.429
# 258745                 NaN        5662.0         0.0                0.429
# 258746                 NaN        5662.0         0.0                0.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 258742  ...          30.7                  36.791                         1.7
# 258743  ...          30.7                  36.791                         1.7
# 258744  ...          30.7                  36.791                         1.7
# 258745  ...          30.7                  36.791                         1.7
# 258746  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 258742            61.49                    0.571  16320539.0
# 258743            61.49                    0.571  16320539.0
# 258744            61.49                    0.571  16320539.0
# 258745            61.49                    0.571  16320539.0
# 258746            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 258742                                   NaN                          NaN
# 258743                                   NaN                          NaN
# 258744                                   NaN                          NaN
# 258745                                   NaN                          NaN
# 258746                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 258742               NaN                                      NaN
# 258743               NaN                                      NaN
# 258744               NaN                                      NaN
# 258745               NaN                                      NaN
# 258746               NaN                                      NaN
#
# [258747 rows x 67 columns]

# %%
#show first five row of the data
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
#show last five row of the data
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 258742      ZWE    Africa  Zimbabwe  2023-02-15     263642.0      559.0
# 258743      ZWE    Africa  Zimbabwe  2023-02-16     263642.0        NaN
# 258744      ZWE    Africa  Zimbabwe  2023-02-17     263642.0        NaN
# 258745      ZWE    Africa  Zimbabwe  2023-02-18     263642.0        NaN
# 258746      ZWE    Africa  Zimbabwe  2023-02-19     263642.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 258742              79.857        5662.0         3.0                0.429
# 258743                 NaN        5662.0         0.0                0.429
# 258744                 NaN        5662.0         0.0                0.429
# 258745                 NaN        5662.0         0.0                0.429
# 258746                 NaN        5662.0         0.0                0.429
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 258742  ...          30.7                  36.791                         1.7
# 258743  ...          30.7                  36.791                         1.7
# 258744  ...          30.7                  36.791                         1.7
# 258745  ...          30.7                  36.791                         1.7
# 258746  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 258742            61.49                    0.571  16320539.0
# 258743            61.49                    0.571  16320539.0
# 258744            61.49                    0.571  16320539.0
# 258745            61.49                    0.571  16320539.0
# 258746            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 258742                                   NaN                          NaN
# 258743                                   NaN                          NaN
# 258744                                   NaN                          NaN
# 258745                                   NaN                          NaN
# 258746                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 258742               NaN                                      NaN
# 258743               NaN                                      NaN
# 258744               NaN                                      NaN
# 258745               NaN                                      NaN
# 258746               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
#show the count of rows and columns in the dataframe
df.shape
# Out:
# (258747, 67)

# %%
#to find missing values
df.isna().sum()
# Out:
# iso_code                                        0
# continent                                   14519
# location                                        0
# date                                            0
# total_cases                                 14568
#                                             ...
# population                                   1109
# excess_mortality_cumulative_absolute       250098
# excess_mortality_cumulative                250098
# excess_mortality                           250098
# excess_mortality_cumulative_per_million    250098
# Length: 67, dtype: int64

# %%
#show basic summary of data such as count,min,max,unique_values
df.describe(include='all')
# Out:
#        iso_code continent   location        date   total_cases     new_cases  \
# count    258747    244228     258747      258747  2.441790e+05  2.438290e+05
# unique      248         6        248        1146           NaN           NaN
# top         ARG    Europe  Argentina  2021-09-19           NaN           NaN
# freq       1146     59168       1146         247           NaN           NaN
# mean        NaN       NaN        NaN         NaN  5.297678e+06  1.178470e+04
# std         NaN       NaN        NaN         NaN  3.257239e+07  8.204663e+04
# min         NaN       NaN        NaN         NaN  1.000000e+00  0.000000e+00
# 25%         NaN       NaN        NaN         NaN  5.754000e+03  0.000000e+00
# 50%         NaN       NaN        NaN         NaN  6.213800e+04  3.700000e+01
# 75%         NaN       NaN        NaN         NaN  6.443560e+05  8.220000e+02
# max         NaN       NaN        NaN         NaN  6.739415e+08  4.082890e+06
#
#         new_cases_smoothed  total_deaths     new_deaths  new_deaths_smoothed  \
# count         2.426250e+05  2.245060e+05  224387.000000        223201.000000
# unique                 NaN           NaN            NaN                  NaN
# top                    NaN           NaN            NaN                  NaN
# freq                   NaN           NaN            NaN                  NaN
# mean          1.183299e+04  7.991636e+04     127.078841           127.652062
# std           7.976279e+04  4.071267e+05     737.116423           683.281768
# min           0.000000e+00  1.000000e+00       0.000000             0.000000
# 25%           4.429000e+00  1.250000e+02       0.000000             0.000000
# 50%           7.714300e+01  1.361000e+03       0.000000             1.143000
# 75%           1.003000e+03  1.100000e+04      11.000000            13.429000
# max           3.436562e+06  6.862848e+06   60900.000000         14860.286000
#
#         ...   male_smokers  handwashing_facilities  \
# count   ...  155510.000000           102608.000000
# unique  ...            NaN                     NaN
# top     ...            NaN                     NaN
# freq    ...            NaN                     NaN
# mean    ...      32.820919               50.926763
# std     ...      13.539242               31.897188
# min     ...       7.700000                1.188000
# 25%     ...      21.600000               20.859000
# 50%     ...      33.100000               49.839000
# 75%     ...      41.300000               83.241000
# max     ...      78.100000              100.000000
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                185415.000000    237494.000000            203265.000000
# unique                         NaN              NaN                      NaN
# top                            NaN              NaN                      NaN
# freq                           NaN              NaN                      NaN
# mean                      3.090653        73.596373                 0.724533
# std                       2.552283         7.445865                 0.149530
# min                       0.100000        53.280000                 0.394000
# 25%                       1.300000        69.500000                 0.602000
# 50%                       2.500000        75.050000                 0.742000
# 75%                       4.200000        79.070000                 0.838000
# max                      13.800000        86.750000                 0.957000
#
#           population  excess_mortality_cumulative_absolute  \
# count   2.576380e+05                          8.649000e+03
# unique           NaN                                   NaN
# top              NaN                                   NaN
# freq             NaN                                   NaN
# mean    1.404975e+08                          5.273396e+04
# std     6.915804e+08                          1.433321e+05
# min     4.700000e+01                         -3.772610e+04
# 25%     8.367830e+05                          9.320001e+01
# 50%     6.871547e+06                          7.149899e+03
# 75%     3.369661e+07                          3.811930e+04
# max     7.975105e+09                          1.273323e+06
#
#         excess_mortality_cumulative  excess_mortality  \
# count                   8649.000000       8649.000000
# unique                          NaN               NaN
# top                             NaN               NaN
# freq                            NaN               NaN
# mean                      10.335603         14.090851
# std                       13.192857         25.875053
# min                      -28.450000        -95.920000
# 25%                        1.080000          0.190000
# 50%                        8.010000          7.620000
# 75%                       16.310000         19.230000
# max                       76.550000        376.770000
#
#         excess_mortality_cumulative_per_million
# count                               8649.000000
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                1514.390390
# std                                 1856.830173
# min                                -1984.281600
# 25%                                   56.186893
# 50%                                  944.000850
# 75%                                 2428.449000
# max                                10251.770000
#
# [11 rows x 67 columns]

# %%
#drop the specific column or row of the dataset
df.drop(['new_cases_smoothed'],axis=1,inplace=True)
df.drop(['new_deaths_smoothed','new_cases_per_million','total_cases_per_million'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (258747, 63)

# %%
#rename the column name,row name,index
df.rename(columns={'date':'Date','location':'Country','continent':'Continent','iso_code':'ISO_code'},inplace=True)

# %%
df
# Out:
#        ISO_code Continent      Country        Date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 258742      ZWE    Africa     Zimbabwe  2023-02-15     263642.0      559.0
# 258743      ZWE    Africa     Zimbabwe  2023-02-16     263642.0        NaN
# 258744      ZWE    Africa     Zimbabwe  2023-02-17     263642.0        NaN
# 258745      ZWE    Africa     Zimbabwe  2023-02-18     263642.0        NaN
# 258746      ZWE    Africa     Zimbabwe  2023-02-19     263642.0        NaN
#
#         total_deaths  new_deaths  new_cases_smoothed_per_million  \
# 0                NaN         NaN                             NaN
# 1                NaN         NaN                             NaN
# 2                NaN         NaN                             NaN
# 3                NaN         NaN                             NaN
# 4                NaN         NaN                             NaN
# ...              ...         ...                             ...
# 258742        5662.0         3.0                           4.893
# 258743        5662.0         0.0                             NaN
# 258744        5662.0         0.0                             NaN
# 258745        5662.0         0.0                             NaN
# 258746        5662.0         0.0                             NaN
#
#         total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# 0                            NaN  ...           NaN                  37.746
# 1                            NaN  ...           NaN                  37.746
# 2                            NaN  ...           NaN                  37.746
# 3                            NaN  ...           NaN                  37.746
# 4                            NaN  ...           NaN                  37.746
# ...                          ...  ...           ...                     ...
# 258742                   346.925  ...          30.7                  36.791
# 258743                   346.925  ...          30.7                  36.791
# 258744                   346.925  ...          30.7                  36.791
# 258745                   346.925  ...          30.7                  36.791
# 258746                   346.925  ...          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 258742                         1.7            61.49                    0.571
# 258743                         1.7            61.49                    0.571
# 258744                         1.7            61.49                    0.571
# 258745                         1.7            61.49                    0.571
# 258746                         1.7            61.49                    0.571
#
#         population  excess_mortality_cumulative_absolute  \
# 0       41128772.0                                   NaN
# 1       41128772.0                                   NaN
# 2       41128772.0                                   NaN
# 3       41128772.0                                   NaN
# 4       41128772.0                                   NaN
# ...            ...                                   ...
# 258742  16320539.0                                   NaN
# 258743  16320539.0                                   NaN
# 258744  16320539.0                                   NaN
# 258745  16320539.0                                   NaN
# 258746  16320539.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 258742                          NaN               NaN
# 258743                          NaN               NaN
# 258744                          NaN               NaN
# 258745                          NaN               NaN
# 258746                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 258742                                      NaN
# 258743                                      NaN
# 258744                                      NaN
# 258745                                      NaN
# 258746                                      NaN
#
# [258747 rows x 63 columns]

# %%
#list the continent name
continent_unique=list(df.Continent.unique())
continent_unique
# Out:
# ['Asia', nan, 'Europe', 'Africa', 'North America', 'South America', 'Oceania']

# %%
#replacing the missing_value by simpleImputer to a constant_value
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='constant')
df2=pd.DataFrame(imputer.fit_transform(df),columns=df.columns)

# %%
df2
# Out:
#        ISO_code Continent      Country        Date total_cases      new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24         5.0            5.0
# 1           AFG      Asia  Afghanistan  2020-02-25         5.0            0.0
# 2           AFG      Asia  Afghanistan  2020-02-26         5.0            0.0
# 3           AFG      Asia  Afghanistan  2020-02-27         5.0            0.0
# 4           AFG      Asia  Afghanistan  2020-02-28         5.0            0.0
# ...         ...       ...          ...         ...         ...            ...
# 258742      ZWE    Africa     Zimbabwe  2023-02-15    263642.0          559.0
# 258743      ZWE    Africa     Zimbabwe  2023-02-16    263642.0  missing_value
# 258744      ZWE    Africa     Zimbabwe  2023-02-17    263642.0  missing_value
# 258745      ZWE    Africa     Zimbabwe  2023-02-18    263642.0  missing_value
# 258746      ZWE    Africa     Zimbabwe  2023-02-19    263642.0  missing_value
#
#          total_deaths     new_deaths new_cases_smoothed_per_million  \
# 0       missing_value  missing_value                  missing_value
# 1       missing_value  missing_value                  missing_value
# 2       missing_value  missing_value                  missing_value
# 3       missing_value  missing_value                  missing_value
# 4       missing_value  missing_value                  missing_value
# ...               ...            ...                            ...
# 258742         5662.0            3.0                          4.893
# 258743         5662.0            0.0                  missing_value
# 258744         5662.0            0.0                  missing_value
# 258745         5662.0            0.0                  missing_value
# 258746         5662.0            0.0                  missing_value
#
#        total_deaths_per_million  ...   male_smokers handwashing_facilities  \
# 0                 missing_value  ...  missing_value                 37.746
# 1                 missing_value  ...  missing_value                 37.746
# 2                 missing_value  ...  missing_value                 37.746
# 3                 missing_value  ...  missing_value                 37.746
# 4                 missing_value  ...  missing_value                 37.746
# ...                         ...  ...            ...                    ...
# 258742                  346.925  ...           30.7                 36.791
# 258743                  346.925  ...           30.7                 36.791
# 258744                  346.925  ...           30.7                 36.791
# 258745                  346.925  ...           30.7                 36.791
# 258746                  346.925  ...           30.7                 36.791
#
#        hospital_beds_per_thousand life_expectancy human_development_index  \
# 0                             0.5           64.83                   0.511
# 1                             0.5           64.83                   0.511
# 2                             0.5           64.83                   0.511
# 3                             0.5           64.83                   0.511
# 4                             0.5           64.83                   0.511
# ...                           ...             ...                     ...
# 258742                        1.7           61.49                   0.571
# 258743                        1.7           61.49                   0.571
# 258744                        1.7           61.49                   0.571
# 258745                        1.7           61.49                   0.571
# 258746                        1.7           61.49                   0.571
#
#         population excess_mortality_cumulative_absolute  \
# 0       41128772.0                        missing_value
# 1       41128772.0                        missing_value
# 2       41128772.0                        missing_value
# 3       41128772.0                        missing_value
# 4       41128772.0                        missing_value
# ...            ...                                  ...
# 258742  16320539.0                        missing_value
# 258743  16320539.0                        missing_value
# 258744  16320539.0                        missing_value
# 258745  16320539.0                        missing_value
# 258746  16320539.0                        missing_value
#
#        excess_mortality_cumulative excess_mortality  \
# 0                    missing_value    missing_value
# 1                    missing_value    missing_value
# 2                    missing_value    missing_value
# 3                    missing_value    missing_value
# 4                    missing_value    missing_value
# ...                            ...              ...
# 258742               missing_value    missing_value
# 258743               missing_value    missing_value
# 258744               missing_value    missing_value
# 258745               missing_value    missing_value
# 258746               missing_value    missing_value
#
#        excess_mortality_cumulative_per_million
# 0                                missing_value
# 1                                missing_value
# 2                                missing_value
# 3                                missing_value
# 4                                missing_value
# ...                                        ...
# 258742                           missing_value
# 258743                           missing_value
# 258744                           missing_value
# 258745                           missing_value
# 258746                           missing_value
#
# [258747 rows x 63 columns]

# %%
#divide given data into different group of subsets
df3=df2.groupby(['Date','Country']) [['total_cases','total_deaths','total_vaccinations']].sum().reset_index()
df3
# Out:
#               Date            Country    total_cases   total_deaths  \
# 0       2020-01-01          Argentina  missing_value  missing_value
# 1       2020-01-01             Mexico  missing_value  missing_value
# 2       2020-01-02          Argentina  missing_value  missing_value
# 3       2020-01-02             Mexico  missing_value  missing_value
# 4       2020-01-03          Argentina  missing_value  missing_value
# ...            ...                ...            ...            ...
# 258742  2023-02-19  Wallis and Futuna         3427.0            7.0
# 258743  2023-02-19              World    673941526.0      6862848.0
# 258744  2023-02-19              Yemen        11945.0         2159.0
# 258745  2023-02-19             Zambia       342317.0         4051.0
# 258746  2023-02-19           Zimbabwe       263642.0         5662.0
#
#        total_vaccinations
# 0           missing_value
# 1           missing_value
# 2           missing_value
# 3           missing_value
# 4           missing_value
# ...                   ...
# 258742      missing_value
# 258743      13293920837.0
# 258744      missing_value
# 258745      missing_value
# 258746      missing_value
#
# [258747 rows x 5 columns]

# %%
#replace the missing_value by 0 using SimpleImputer of total_cases,total_deaths,total_vaccination
df3['total_cases'].replace({'missing_value':0},inplace=True)
df3["total_deaths"].replace({"missing_value":0},inplace=True)
df3["total_vaccinations"].replace({"missing_value":0},inplace=True)
df3
# Out:
#               Date            Country  total_cases  total_deaths  \
# 0       2020-01-01          Argentina          0.0           0.0
# 1       2020-01-01             Mexico          0.0           0.0
# 2       2020-01-02          Argentina          0.0           0.0
# 3       2020-01-02             Mexico          0.0           0.0
# 4       2020-01-03          Argentina          0.0           0.0
# ...            ...                ...          ...           ...
# 258742  2023-02-19  Wallis and Futuna       3427.0           7.0
# 258743  2023-02-19              World  673941526.0     6862848.0
# 258744  2023-02-19              Yemen      11945.0        2159.0
# 258745  2023-02-19             Zambia     342317.0        4051.0
# 258746  2023-02-19           Zimbabwe     263642.0        5662.0
#
#         total_vaccinations
# 0             0.000000e+00
# 1             0.000000e+00
# 2             0.000000e+00
# 3             0.000000e+00
# 4             0.000000e+00
# ...                    ...
# 258742        0.000000e+00
# 258743        1.329392e+10
# 258744        0.000000e+00
# 258745        0.000000e+00
# 258746        0.000000e+00
#
# [258747 rows x 5 columns]

# %%
#total countries where total_deaths is greater than 1000000
df4=df3[df3["total_deaths"]>1000000]
countries=df4["Country"].unique()
len(countries)
# Out:
# 10

# %%
#countries total_deaths is greater than 1000000
country_deaths_greaterthan1000000=list(df4.Country.unique())
country_deaths_greaterthan1000000
# Out:
# ['World',
#  'High income',
#  'Upper middle income',
#  'Europe',
#  'South America',
#  'Asia',
#  'Lower middle income',
#  'North America',
#  'European Union',
#  'United States']

# %%
#using scatter plotting shows total_deaths,total_cases,total_vaccinations of those 8 countries
for idx in range(0,len(countries)):
 c=df4.loc[df4['Country']==countries[idx]].reset_index()
 plt.scatter(np.arange(0,len(c)),c['total_cases'],color='blue',label="total_cases")
 plt.scatter(np.arange(0,len(c)),c['total_deaths'],color='red',label='total_deaths')
 plt.scatter(np.arange(0,len(c)),c['total_vaccinations'],color='green',label='total_vaccinations')
 plt.title(countries[idx])
 plt.xlabel('number of days since first suspect')
 plt.ylabel('number of cases')
 plt.legend()
 plt.show()

# %%
#group all other countries
df5=df4.groupby(['Country'])[['Country', 'total_cases', 'total_deaths']].sum().reset_index()
C = df5
plt.scatter (np.arange(0,len (C)),C['total_cases'], color="blue", label="total_cases")
plt.scatter (np.arange(0,len (C)),C['total_deaths' ], color="red", label="total_deaths")
plt.title("World")
plt.xlabel("Number of days since first suspect")
plt.ylabel("Number of cases")
plt.legend()
plt.show()
# Out:
# <ipython-input-129-a796064faa51>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df5=df4.groupby(['Country'])[['Country', 'total_cases', 'total_deaths']].sum().reset_index()

# %%
#another analysis by date for total_deaths is greater than 1000000
date= df4[ 'Date'].unique()
len (date)
# Out:
# 887

# %%
df6=df4.groupby([ 'Date']) [['Date', 'total_cases', 'total_deaths']].sum().reset_index()
C=df6
plt.scatter(np.arange(0,len (C)),C['total_cases'],color="blue",label="total_cases")
plt.scatter(np.arange(0,len (C)),C['total_deaths'],color="red",label="total_deaths")
plt.title("World")
plt.xlabel("Number of days since first suspect")
plt.ylabel("Number of cases")
plt.legend()
plt.show()
# Out:
# <ipython-input-131-e650c74d6a54>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df6=df4.groupby([ 'Date']) [['Date', 'total_cases', 'total_deaths']].sum().reset_index()
